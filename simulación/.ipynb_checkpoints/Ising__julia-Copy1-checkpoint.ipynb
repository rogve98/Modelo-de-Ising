# %%
using Plots
using Roots
using BenchmarkTools
using Statistics

# %% [markdown]
# ## 3.1 Armado de la red y cálculo de la energía del sistema
# Consideren una red cuadrada de $N\times  N$, con $N^2$ el número de átomos que componen al sistema.

# %%
#También declaramos las constantes
#definimos la constante de boltzman como 1 para que los resultados tengan mejor visualización
kb = 1
#Se declara con esee valor J por consenso del grupo :)
J=0.5;

# %%
function Malla_fria(N)
    return  [1 for i in 1:N^2]
end
# Out:
# Malla_fria (generic function with 1 method)

# %%
function Malla(N)
    return  [rand([-1,1]) for i in 1:N^2]
end
# Out:
# Malla (generic function with 1 method)

# %% [markdown]
# Generen una lista con los primeros vecinos de cada sitio implementando condiciones periódicas a la frontera (lo cual es equivalente a transformar al plano en un toro). De esta forma, todos los sitios de la red tienen 4 vecinos.

# %%
function Vecinos(N) #Vecinos
    N² = N*N
    v = zeros(Int,(N²,4))
    #Neighbor.site: (up, right,  down, left)
    for j in 1:N²
    #up
        if j+N<= N²
            v[j,1] = j+N 

        elseif j+N>N²
            v[j,1] = j - N*(N-1)
        end
    #right
        if j%N != 0 
            v[j,2] = j+1
        elseif j%N ==0
            v[j,2] = j-N+1 
        end
    #down
        if j-N>=1
            v[j,3] = j-N
        elseif j-N<1
            v[j,3] =j+N*(N-1)
        end
    #left    
        if (j-1)%N != 0
            v[j,4] = j-1
        elseif (j-1)%N ==0
            v[j,4] = j+N-1
        end
                
    end
            
    return v
end
# Out:
# Vecinos (generic function with 1 method)

# %%
Red = Malla(3)
Vecinos(3)
# Out:
# 9×4 Array{Int64,2}:
#  4  2  7  3
#  5  3  8  1
#  6  1  9  2
#  7  5  1  6
#  8  6  2  4
#  9  4  3  5
#  1  8  4  9
#  2  9  5  7
#  3  7  6  8

# %% [markdown]
# Ya que hayan hecho esto, calculen la energía de un par de conguraciones de espines y un valor de J.
#
# La energía del sistema si hacemos la aproximación a los primero 4 vecinos es:
#
# $$E=\sum _{<i,j>}-Js_{i}s_{j}$$

# %%
function Energia_total(red_lista,J)
    N² = length(red_lista)
    #generamos los indices de los vecinos
    vecinos_lista = Vecinos(Int(sqrt(N²)))
    #Creamos un arreglo donde iremos sumando cada elemento de la suma de la energía total
    energia_total = 0
    #Creamos un arreglo que obtenga la energía de interacción de cada elemento de la red
    for i in 1:N²
        #Obtenemos los indices de los vecinos
        vecinosi= vecinos_lista[i]
        for j in vecinosi
            energia_total += red_lista[i]*red_lista[j]
        end
    
    end
    return energia_total*(-J)
end
# Out:
# Energia_total (generic function with 1 method)

# %%
function magnetizacion(red_lista)
    return sum(red_lista)
end
# Out:
# magnetizacion (generic function with 1 method)

# %%
for i in 1:4
    print(i)
end
# Out:
# 1234

# %%
espines =  Malla(3)
J=0.5
vecinos_lista = Vecinos(3)
for j in 1:9
    for i in 1:4 #Multiplicamos spin de la malla por sus vecinos
        dE = 2*J*espines[j]*espines[Int(vecinos_lista[j][i])]
        print(dE)
    end
end
# Out:
# 1.0
# BoundsError
#
# Stacktrace:
#  [1] getindex(::Int64, ::Int64) at .\number.jl:78
#  [2] top-level scope at .\In[131]:6
#  [3] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %%
rand(1)
# Out:
# 1-element Array{Float64,1}:
#  0.2866473831524521

# %%
function Termalizacion(kt, espines, Q, J)
    N = Int(sqrt(length(espines)))
    N² = N*N
    Flip = []
    flip_contador = 0
    vecinos_lista = Vecinos(N)
    efinc = []
    magnefinc = []
    dE = 0
        for j in 1:N²
        #Obtenemos los indices de los vecinos
        vecinosj= vecinos_lista[j]
        for i in vecinosj
            dE += 2*J*espines[j]*espines[i]
            pob = exp(-dE/kt)
            if dE<0 || pob>rand(1)
                espines[j] = -espines[j]
                flip_contador += 1
            end
                en = energia(espines, 0.5)
                m = sum(espines)
                energias = append!(energias, en)
                magne = append!(magne, m)
                Flip = append!(Flip,flip_contador)
        end
        enfinc = append!(enfinc, energias)
        magnefinc = append!(magnefinc, abs(magne))
        end
    return Flip, enfinc, magnefinc
end
# Out:
# Termalizacion (generic function with 1 method)

# %%
Red20 = Malla_fria(20) 
Red40 = Malla_fria(40) 
Red50 = Malla_fria(50) 
Red100 = Malla_fria(100);

# %%
Flip20, E20, M20 = Termalizacion(1.5, Red20, 7000, 0.5)
Flip40, E40, M40 = Termalizacion(1.5, Red40, 7000, 0.5)
Flip50, E50, M50 = Termalizacion(1.5, Red50, 7000, 0.5)
Flip100, E100, M100 = Termalizacion(1.5, Red100, 7000, 0.5);
# Out:
# MethodError: no method matching isless(::Array{Float64,1}, ::Float64)
# Closest candidates are:
#   isless(::Missing, ::Any) at missing.jl:87
#   isless(::Float64, ::Float64) at float.jl:465
#   isless(::AbstractFloat, ::AbstractFloat) at operators.jl:165
#   ...
#
# Stacktrace:
#  [1] <(::Array{Float64,1}, ::Float64) at .\operators.jl:277
#  [2] >(::Float64, ::Array{Float64,1}) at .\operators.jl:303
#  [3] Termalizacion(::Float64, ::Array{Int64,1}, ::Int64, ::Float64) at .\In[157]:16
#  [4] top-level scope at In[158]:1
#  [5] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %%
plot!(Flip20, E20./20^2,label = "Malla de 20x20")
plot!(Flip40, E40./40^2,label = "Malla de 40x40")
plot!(Flip50, E50./50^2,label = "Malla de 50x50")
plot!(Flip100, E100./100^2,label = "Malla de 100x100")
plot!(xlabel = "Spin flips", ylabel ="<ϵ>")
# Out:
# BoundsError: attempt to access 2406-element Array{Float64,1} at index [1:2426]
#
# Stacktrace:
#  [1] throw_boundserror(::Array{Float64,1}, ::Tuple{UnitRange{Int64}}) at .\abstractarray.jl:541
#  [2] checkbounds at .\abstractarray.jl:506 [inlined]
#  [3] getindex(::Array{Float64,1}, ::UnitRange{Int64}) at .\array.jl:815
#  [4] gr_draw_segments(::Plots.Series, ::Array{Float64,1}, ::Array{Float64,1}, ::Nothing, ::Tuple{Float64,Float64}) at C:\Users\sammy\.julia\packages\Plots\SjqWU\src\backends\gr.jl:1642
#  [5] gr_add_series(::Plots.Subplot{Plots.GRBackend}, ::Plots.Series) at C:\Users\sammy\.julia\packages\Plots\SjqWU\src\backends\gr.jl:1559
#  [6] gr_display(::Plots.Subplot{Plots.GRBackend}, ::Measures.Length{:mm,Float64}, ::Measures.Length{:mm,Float64}, ::Array{Float64,1}) at C:\Users\sammy\.julia\packages\Plots\SjqWU\src\backends\gr.jl:935
#  [7] gr_display(::Plots.Plot{Plots.GRBackend}, ::String) at C:\Users\sammy\.julia\packages\Plots\SjqWU\src\backends\gr.jl:626
#  [8] _show(::Base.GenericIOBuffer{Array{UInt8,1}}, ::MIME{Symbol("image/svg+xml")}, ::Plots.Plot{Plots.GRBackend}) at C:\Users\sammy\.julia\packages\Plots\SjqWU\src\backends\gr.jl:1810
#  [9] show(::Base.GenericIOBuffer{Array{UInt8,1}}, ::MIME{Symbol("image/svg+xml")}, ::Plots.Plot{Plots.GRBackend}) at C:\Users\sammy\.julia\packages\Plots\SjqWU\src\output.jl:215
#  [10] sprint(::Function, ::MIME{Symbol("image/svg+xml")}, ::Vararg{Any,N} where N; context::Nothing, sizehint::Int64) at .\strings\io.jl:105
#  [11] sprint at .\strings\io.jl:101 [inlined]
#  [12] _ijulia_display_dict(::Plots.Plot{Plots.GRBackend}) at C:\Users\sammy\.julia\packages\Plots\SjqWU\src\ijulia.jl:53
#  [13] display_dict(::Plots.Plot{Plots.GRBackend}) at C:\Users\sammy\.julia\packages\Plots\SjqWU\src\init.jl:77
#  [14] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [15] invokelatest at .\essentials.jl:709 [inlined]
#  [16] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\sammy\.julia\packages\IJulia\e8kqU\src\execute_request.jl:112
#  [17] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [18] invokelatest at .\essentials.jl:709 [inlined]
#  [19] eventloop(::ZMQ.Socket) at C:\Users\sammy\.julia\packages\IJulia\e8kqU\src\eventloop.jl:8
#  [20] (::IJulia.var"#15#18")() at .\task.jl:356

# %%
Red20_f = Malla_fria(20)
Red40_f = Malla_fria(40)
Red50_f = Malla_fria(50)
Red100_f = Malla_fria(100);

# %%
Flip20_f, E20_f, M20_f = Termalizacion(1.5, Red20_f, 7000, 0.5)
Flip40_f, E40_f, M40_f = Termalizacion(1.5, Red40_f, 7000, 0.5)
Flip50_f, E50_f, M50_f = Termalizacion(1.5, Red50_f, 7000, 0.5)
Flip100_f, E100_f, M100_f = Termalizacion(1.5, Red0100, 7000, 0.5);

# %%
plot!(Flip20_f,E20_f./(20^2), label = "Malla de 20x20")
plot!(Flip40_f,E40_f./(40^2), label = "Malla de 40x40")
plot!(Flip50_f,E50_f./(50^2), label = "Malla de 50x50")
plot!(Flip100_f,E100_f./(100^2), label = "Malla de 100x100")
plot!(title = "Configuración caliente", xlabel = "Spin flips", ylabel ="<ϵ>")
